# %% [markdown]
# # Fine-Tuning GPT-4.1-mini for Named Entity Recognition (NER)
# ---

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /Users/lezanhawizy/github/AlloyMind/.venv/lib/python3.12/site-packages (2.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/lezanhawizy/github/AlloyMind/.venv/lib/python3.12/site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/lezanhawizy/github/AlloyMind/.venv/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/lezanhawizy/github/AlloyMind/.venv/lib/python3.12/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/lezanhawizy/github/AlloyMind/.venv/lib/python3.12/site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/lezanhawizy/github/AlloyMind/.venv/lib/python3.12/site-packages (from openai) (2.12.4)
# Requirement already satisfied: sniffio in /Users/lezanhawizy/github/AlloyMind/.venv/lib/python3.12/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/lezanhawizy/github/AlloyMind/.venv/lib/python3.12/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/lezanhawizy/github/AlloyMind/.venv/lib/python3.12/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/lezanhawizy/github/AlloyMind/.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /Users/lezanhawizy/github/AlloyMind/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/lezanhawizy/github/AlloyMind/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/lezanhawizy/github/AlloyMind/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/lezanhawizy/github/AlloyMind/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/lezanhawizy/github/AlloyMind/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/lezanhawizy/github/AlloyMind/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import json
from openai import OpenAI

# %% [markdown]
# ### Initialise

# %%
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %% [markdown]
# ###  Upload Training File

# %%
# Make sure the JSONL file is formatted according to OpenAI's fine-tuning schema
size = 1500
train_file_path = f"output_data/finetuned_data/train.jsonl"
val_file_path = f"output_data/finetuned_data/val.jsonl"
test_file_path = f"output_data/finetuned_data/test.jsonl"
train_file = client.files.create(
    file=open(train_file_path, "rb"),
    purpose="fine-tune"
)
val_file = client.files.create(
    file=open(val_file_path, "rb"),
    purpose="fine-tune"
)
training_file_id = train_file.id
val_file_id = val_file.id
print("Training file uploaded.")
print("Training File ID:", training_file_id)
print("Validation File ID:", val_file_id)
# Out:
# Training file uploaded.
# Training File ID: file-RQxAgs4EHuEriMXdYcrZPE
# Validation File ID: file-JcVJE3LEFoxZDZ6iGbzika

# %% [markdown]
# ### Create Fine-Tuning Job

# %%
fine_tune_response = client.fine_tuning.jobs.create(
    training_file=training_file_id,
     validation_file=val_file_id,
    model= "gpt-4.1-mini-2025-04-14" #gpt-3.5-turbo #gpt-4o-mini-2024-07-18 #gpt-4.1-mini-2025-04-14
)

job_id = fine_tune_response.id
print("Fine-tuning job started.")
print("Job ID:", job_id)
# Out:
# Fine-tuning job started.
# Job ID: ftjob-cB5n6fiSMtucxBeo70HzPNSe

# %% [markdown]
# ### Retrieve Fine-Tuning Job Info

# %%
# job = client.fine_tuning.jobs.retrieve(job_id) #"ftjob-m80aY0hp4Z2d6TOLD9zrxVwd"
job = client.fine_tuning.jobs.retrieve(job_id) #"ftjob-m80aY0hp4Z2d6TOLD9zrxVwd"
print("📄 Fine-tuning job status:")
print(job)
# Out:
# 📄 Fine-tuning job status:
# FineTuningJob(id='ftjob-cB5n6fiSMtucxBeo70HzPNSe', created_at=1766517567, error=Error(code=None, message=None, param=None), fine_tuned_model=None, finished_at=None, hyperparameters=Hyperparameters(batch_size='auto', learning_rate_multiplier='auto', n_epochs='auto'), model='gpt-4.1-mini-2025-04-14', object='fine_tuning.job', organization_id='org-Naf8JqIqj78cDx1u4sa0mO5I', result_files=[], seed=1600217642, status='validating_files', trained_tokens=None, training_file='file-RQxAgs4EHuEriMXdYcrZPE', validation_file='file-JcVJE3LEFoxZDZ6iGbzika', estimated_finish=None, integrations=[], metadata=None, method=Method(type='supervised', dpo=None, reinforcement=None, supervised=SupervisedMethod(hyperparameters=SupervisedHyperparameters(batch_size='auto', learning_rate_multiplier='auto', n_epochs='auto'))), user_provided_suffix=None, usage_metrics=None, shared_with_openai=False, eval_id=None)

# %%
job
# Out:
# FineTuningJob(id='ftjob-cB5n6fiSMtucxBeo70HzPNSe', created_at=1766517567, error=Error(code=None, message=None, param=None), fine_tuned_model=None, finished_at=None, hyperparameters=Hyperparameters(batch_size='auto', learning_rate_multiplier='auto', n_epochs='auto'), model='gpt-4.1-mini-2025-04-14', object='fine_tuning.job', organization_id='org-Naf8JqIqj78cDx1u4sa0mO5I', result_files=[], seed=1600217642, status='validating_files', trained_tokens=None, training_file='file-RQxAgs4EHuEriMXdYcrZPE', validation_file='file-JcVJE3LEFoxZDZ6iGbzika', estimated_finish=None, integrations=[], metadata=None, method=Method(type='supervised', dpo=None, reinforcement=None, supervised=SupervisedMethod(hyperparameters=SupervisedHyperparameters(batch_size='auto', learning_rate_multiplier='auto', n_epochs='auto'))), user_provided_suffix=None, usage_metrics=None, shared_with_openai=False, eval_id=None)

# %% [markdown]
# ### Generate Predictions from the Fine-Tuned Model

# %%
# (Note: Ensure the job is completed and `fine_tuned_model` is available before running this)

import time

# ⏳ Wait or poll until fine-tuning job is complete
while job.fine_tuned_model is None:
    print("⏳ Waiting for fine-tuned model to be ready...")
    time.sleep(10)
    job = client.fine_tuning.jobs.retrieve(job_id)

model_id = job.fine_tuned_model
print("✅ Fine-tuned model is ready:", model_id)
# Out:
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ⏳ Waiting for fine-tuned model to be ready...
# ✅ Fine-tuned model is ready: ft:gpt-4.1-mini-2025-04-14:digital-science-dimensions::Cq2L1o9E

# %%
client.fine_tuning.jobs.retrieve(job_id)
# Out:
# FineTuningJob(id='ftjob-cB5n6fiSMtucxBeo70HzPNSe', created_at=1766517567, error=Error(code=None, message=None, param=None), fine_tuned_model='ft:gpt-4.1-mini-2025-04-14:digital-science-dimensions::Cq2L1o9E', finished_at=1766518076, hyperparameters=Hyperparameters(batch_size=1, learning_rate_multiplier=2.0, n_epochs=3), model='gpt-4.1-mini-2025-04-14', object='fine_tuning.job', organization_id='org-Naf8JqIqj78cDx1u4sa0mO5I', result_files=['file-Np5B7PHnJrPPkukQ15bjmi'], seed=1600217642, status='succeeded', trained_tokens=92502, training_file='file-RQxAgs4EHuEriMXdYcrZPE', validation_file='file-JcVJE3LEFoxZDZ6iGbzika', estimated_finish=None, integrations=[], metadata=None, method=Method(type='supervised', dpo=None, reinforcement=None, supervised=SupervisedMethod(hyperparameters=SupervisedHyperparameters(batch_size=1, learning_rate_multiplier=2.0, n_epochs=3))), user_provided_suffix=None, usage_metrics=None, shared_with_openai=False, eval_id=None)

# %% [markdown]
# ### Save Predictions

# %%
import json
def generate_predictions(input_file, output_file):
    count = 0

    with open(input_file, 'r', encoding='utf-8') as f:
        examples = [json.loads(line) for line in f]

    with open(output_file, 'w', encoding='utf-8') as out_f:
        for ex in examples:
            user_input = ex["messages"][1]["content"]
            system_prompt = ex["messages"][0]["content"]

            # Try to extract expected output, default to {}
            try:
                expected_output = json.loads(ex["messages"][2]["content"])
            except json.JSONDecodeError:
                expected_output = {}
                
            
            # Initialize predicted_output and raw_content
            predicted_output = None
            raw_content = None

            response = client.chat.completions.create(
                model=model_id,
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": user_input}
                ],
                temperature=0
            )

            raw_content = response.choices[0].message.content
            try:
                predicted_output = json.loads(raw_content)
            except json.JSONDecodeError:
                predicted_output = None  # Keep as None, will store raw content instead

            result = {
                "input": user_input,
                "predicted": predicted_output,
                "raw_response": raw_content,
                "expected": expected_output,
            }

            out_f.write(json.dumps(result) + "\n")
            count += 1

    print(f"\n✅ {count} predictions saved to: {output_file}")

# %%
output_predictions_path = f"output_gpt4.1_ft.jsonl"

generate_predictions(test_file_path, output_predictions_path)
# Out:
# ✅ 21 predictions saved to: output_gpt4.1_ft.jsonl

# %% [markdown]
# ### Run Prediction Generation

# %% [markdown]
# ### Evaluate predictions

# %%
import math

import json

def parse_value(v):
    try:
        return float(v)
    except:
        return None

def percent_error(expected, predicted):
    if expected is None or predicted is None or expected == 0:
        return None
    return abs((predicted - expected) / expected) * 100

def evaluate_mechanical_properties(row, tolerance_pct=20):
    expected = row.get("expected", {})
    predicted = row.get("predicted", {})
    
    results = {}

    for prop, exp_list in expected.items():
        pred_list = predicted.get(prop, [])

        # If no expected or predicted data
        if not exp_list or not pred_list:
            results[prop] = "NA"
            continue

        exp_item = exp_list[0]

        # Validate expected entry
        if "value" not in exp_item or "temp_c" not in exp_item:
            results[prop] = "NA"
            continue

        exp_val = parse_value(exp_item["value"])
        exp_temp = str(exp_item["temp_c"]).strip()

        # Find predicted value at same temperature
        pred_item = next(
            (p for p in pred_list if str(p.get("temp_c", "")).strip() == exp_temp),
            None
        )

        if not pred_item or "value" not in pred_item:
            results[prop] = "NA"
            continue

        pred_val = parse_value(pred_item["value"])

        err = percent_error(exp_val, pred_val)

        if err is None:
            results[prop] = "NA"
        elif err <= tolerance_pct:
            results[prop] = "Match"
        else:
            results[prop] = "Mismatch"

    return results

def per_property_metrics(rows, tolerance_pct=20):
    metrics = {}  # {property: {TP, FP, FN}}

    for row in rows:
        results = evaluate_mechanical_properties(row, tolerance_pct)

        for prop, match in results.items():
            if prop not in metrics:
                metrics[prop] = {"TP": 0, "FP": 0, "FN": 0}

            if match == "Match":
                metrics[prop]["TP"] += 1
            elif match == "Mismatch":
                metrics[prop]["FP"] += 1
            else:  # NA → expected exists but no usable prediction
                metrics[prop]["FN"] += 1

    report = {}
    for prop, counts in metrics.items():
        TP = counts["TP"]
        FP = counts["FP"]
        FN = counts["FN"]

        precision = TP / (TP + FP) if (TP + FP) else 0.0
        recall = TP / (TP + FN) if (TP + FN) else 0.0
        f1 = (
            2 * precision * recall / (precision + recall)
            if (precision + recall)
            else 0.0
        )

        report[prop] = {
            "precision": round(precision, 4),
            "recall": round(recall, 4),
            "f1": round(f1, 4),
            "TP": TP,
            "FP": FP,
            "FN": FN
        }

    return report


def evaluate_jsonl(file_path, tolerance_pct=10):
    rows = []
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            rows.append(json.loads(line.strip()))

    report = per_property_metrics(rows, tolerance_pct)

    print("\n📊 Per-Property Scores (tolerance:", tolerance_pct, "%)")
    for prop, scores in report.items():
        print(f"\nProperty: {prop}")
        print(scores)

    return report

# %%
evaluate_jsonl(output_predictions_path, tolerance_pct=20)
# Out:
# 📊 Per-Property Scores (tolerance: 20 %)
#
# Property: yield_strength
# {'precision': 0.3889, 'recall': 0.7, 'f1': 0.5, 'TP': 7, 'FP': 11, 'FN': 3}
#
# Property: uts
# {'precision': 0.3889, 'recall': 0.7, 'f1': 0.5, 'TP': 7, 'FP': 11, 'FN': 3}
#
# Property: elongation
# {'precision': 0.2778, 'recall': 0.625, 'f1': 0.3846, 'TP': 5, 'FP': 13, 'FN': 3}
#
# Property: elasticity
# {'precision': 0.9231, 'recall': 0.6, 'f1': 0.7273, 'TP': 12, 'FP': 1, 'FN': 8}
# {'yield_strength': {'precision': 0.3889,
#   'recall': 0.7,
#   'f1': 0.5,
#   'TP': 7,
#   'FP': 11,
#   'FN': 3},
#  'uts': {'precision': 0.3889,
#   'recall': 0.7,
#   'f1': 0.5,
#   'TP': 7,
#   'FP': 11,
#   'FN': 3},
#  'elongation': {'precision': 0.2778,
#   'recall': 0.625,
#   'f1': 0.3846,
#   'TP': 5,
#   'FP': 13,
#   'FN': 3},
#  'elasticity': {'precision': 0.9231,
#   'recall': 0.6,
#   'f1': 0.7273,
#   'TP': 12,
#   'FP': 1,
#   'FN': 8}}
